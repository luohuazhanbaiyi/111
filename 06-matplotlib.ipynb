# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[1,4,2,3]

# %%
fig,ax=plt.subplots()
ax.plot(x,y)
ax.set_xlabel('变量 a',fontproperties='SimHei')
ax.set_ylabel('变量 b',fontproperties='SimHei')
plt.show()
